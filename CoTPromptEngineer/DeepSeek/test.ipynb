# %%
from openai import OpenAI
from prompt import cot_prompt
import pandas as pd
import os; api_key = os.getenv('DEEPSEEK_API')

train_df = pd.read_csv('../data/data4cot/train_cot.csv')
client = OpenAI(api_key=api_key, base_url="https://api.deepseek.com")

train_df['cot'] = ''
for i,row in train_df.iterrows():
    if i >= 7:
        break
    if i%100==0:
        print(i)
        train_df.to_excel('./train_cot.xlsx', index=False)
    query = row['query_with_products']
    label = row['label']
    prompt = cot_prompt.replace('<QUERY>', query).replace('<LABEL>', label)
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(model="deepseek-chat", messages=messages, max_tokens=4096)   
    train_df.loc[i,'cot'] = response.choices[0].message.content
    # break
# for backward compatibility, you can still use `https://api.deepseek.com/v1` as `base_url`.
# print(client.models.list())
# train_df.to_excel('./train_cot.xlsx', index=False)
# Out:
# 0

# %%
train_df_ = pd.read_excel('../train_cot.xlsx')
# train_df.to_excel('./train_cot.xlsx', index=False)

# %%
train_df_
# Out:
#                                     query_with_products  \
# 0     我打算用100万元买三羊马的股票，如果按照三羊马的最高价来计算，我能买多少股呢？问题中提到的...
# 1     我想知道西旅今天的总成交资金和市值是多少问题中提到的产品标准名可能是：西部利得天添金货币市场...
# 2     我如果3个月前用5000块买了国投瑞银锐意改革C，然后又在1个月前购买了1000块，那么我现...
# 3     请问有哪些基金最近一个月中最长的解套期是20天，并且在今年已经创下新高达70次的？问题中提到...
# 4     能告诉我那些在过去六个月里最长时间摆脱亏损状态就是60天，并且在最近一个月的收益表现在同类型...
# ...                                                 ...
# 5455  那些过去五年收益率是29.45%并且最近一年里，如果持有6个月的话，盈利几率只有7.14%的...
# 5456  我要是现在购买10000元恒越研究精选C基金，那么我需要支付的申购费用是多少？问题中提到的产...
# 5457  请问中融大消费A基金的3年来收益率同类排名和风险等级是怎样的？问题中提到的产品标准名可能是：...
# 5458  请问鹏华全球A目前的基金公司是哪家，以及该公司是否有自购行为？问题中提到的产品标准名可能是：...
# 5459  我想知道现在购买诺泰的1000股，卖出时需要缴纳的印花税是多少钱问题中提到的产品标准名可能是...
#
#                                                   label  cot
# 0     {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
# 1     {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
# 2     {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
# 3     {"relevant APIs": [{"api_id": "0", "tool_name"...  NaN
# 4     {"relevant APIs": [{"api_id": "0", "tool_name"...  NaN
# ...                                                 ...  ...
# 5455  {"relevant APIs": [{"api_id": "0", "tool_name"...  NaN
# 5456  {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
# 5457  {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
# 5458  {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
# 5459  {"relevant APIs": [{"api_id": "0", "api_name":...  NaN
#
# [5460 rows x 3 columns]

# %%
train_df
# Out:
#                                     query_with_products  \
# 0     我打算用100万元买三羊马的股票，如果按照三羊马的最高价来计算，我能买多少股呢？问题中提到的...
# 1     我想知道西旅今天的总成交资金和市值是多少问题中提到的产品标准名可能是：西部利得天添金货币市场...
# 2     我如果3个月前用5000块买了国投瑞银锐意改革C，然后又在1个月前购买了1000块，那么我现...
# 3     请问有哪些基金最近一个月中最长的解套期是20天，并且在今年已经创下新高达70次的？问题中提到...
# 4     能告诉我那些在过去六个月里最长时间摆脱亏损状态就是60天，并且在最近一个月的收益表现在同类型...
# ...                                                 ...
# 5455  那些过去五年收益率是29.45%并且最近一年里，如果持有6个月的话，盈利几率只有7.14%的...
# 5456  我要是现在购买10000元恒越研究精选C基金，那么我需要支付的申购费用是多少？问题中提到的产...
# 5457  请问中融大消费A基金的3年来收益率同类排名和风险等级是怎样的？问题中提到的产品标准名可能是：...
# 5458  请问鹏华全球A目前的基金公司是哪家，以及该公司是否有自购行为？问题中提到的产品标准名可能是：...
# 5459  我想知道现在购买诺泰的1000股，卖出时需要缴纳的印花税是多少钱问题中提到的产品标准名可能是...
#
#                                                   label  \
# 0     {"relevant APIs": [{"api_id": "0", "api_name":...
# 1     {"relevant APIs": [{"api_id": "0", "api_name":...
# 2     {"relevant APIs": [{"api_id": "0", "api_name":...
# 3     {"relevant APIs": [{"api_id": "0", "tool_name"...
# 4     {"relevant APIs": [{"api_id": "0", "tool_name"...
# ...                                                 ...
# 5455  {"relevant APIs": [{"api_id": "0", "tool_name"...
# 5456  {"relevant APIs": [{"api_id": "0", "api_name":...
# 5457  {"relevant APIs": [{"api_id": "0", "api_name":...
# 5458  {"relevant APIs": [{"api_id": "0", "api_name":...
# 5459  {"relevant APIs": [{"api_id": "0", "api_name":...
#
#                                                     cot
# 0     思考过程：\n    1. 首先确定这是一个股票查询类任务，因为问题涉及到股票的购买数量计算...
# 1     思考过程：\n    1. 首先，根据问题中的关键词“今天的总成交资金和市值”，可以确定这是...
# 2     思考过程：\n1. 首先，确定这是一个基金查询类任务。问题中提到了两次购买行为，分别是3个月...
# 3     思考过程：\n    1. 首先，确定这是一个条件选基类任务，因为问题涉及到基金的特定指标筛...
# 4     思考过程：\n    1. 首先可以确定这是一个条件选基类任务，因为问题涉及到基金的特定条件...
# ...                                                 ...
# 5455
# 5456
# 5457
# 5458
# 5459
#
# [5460 rows x 3 columns]
